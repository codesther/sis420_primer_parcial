# %%
#nodos para definir el padre, hijo, acciones, accion, dato
class Nodo:
    def __init__(self, estado, hijo=None):
        self.estado = estado
        self.hijo = None
        self.padre = None
        self.accion = None
        self.acciones = None
        self.set_hijo(hijo)

    def set_estado(self, estado):
        self.estado = estado

    def get_estado(self):
        return self.estado

    def set_hijo(self, hijo):
        self.hijo = hijo
        if self.hijo is not None:
            for s in self.hijo:
                s.padre = self

    def get_hijo(self):
        return self.hijo
    
    def set_padre(self, padre):
        self.padre = padre

    def get_padre(self):
        return self.padre
    
    def set_accion(self, accion):
        self.padre = accion

    def get_accion(self):
        return self.accion

    def set_acciones(self, acciones):
        self.acciones = acciones

    def get_acciones(self):
        return self.acciones
    
    def equal(self, Nodo):
        if self.get_estado() == Nodo.get_estado():
            return True
        else:
            return False

    def en_lista(self, lista_nodos):
        enlistado = False
        for n in lista_nodos:
            if self.equal(n):
                enlistado = True
        return enlistado

    def __str__(self):
        return str(self.get_estado())

# %%
#ver si esta vivo o muerto el lobo la cabra y lechuga
# sis e queda el lobo con la cabra se lo come ahi esta muerto
# si se queda la cabra con la oveja se lo come y ahi igual esta muerto
# si el granjero se va al otro lado del rio y deja solos a las tres  coas igual muere 
def muerto_vivo(hijo):
    estado_muertos = [
        [["lo","ov", "le","0"],["0","0","0","pe"]],
        [["lo","ov", "0","0"],["0","0","le","pe"]],
        [["0","ov", "le","0"],["lo","0","0","pe"]],
        [["0","0","0","pe"],["lo","ov", "le","0"]],
        [["0","0","le","pe"],["lo","ov", "0","0"]],
        [["lo","0","0","pe"],["0","ov", "le","0"]]
    ]
    if hijo in estado_muertos:
        return "muerto"
    else:
        return "vivo"

# %%
#crear una funcion para los estados solucion y inicial
def busqueda_BPA_solucion(estado_inicial, solucion):
    resuelto = False
    nodos_visitados = []
    nodos_frontera = []
    nodo_raiz = Nodo(estado_inicial)
    nodos_frontera.append(nodo_raiz)
    
    while (not resuelto) and len(nodos_frontera) != 0:
        nodo_actual = nodos_frontera.pop(0)
        # extraer nodo y añadirlo a visitados
        nodos_visitados.append(nodo_actual)
        if nodo_actual.get_estado() == solucion:
            # solucion encontrada
            resuelto = True
            return nodo_actual
        else:
            # expandir nodos hijo
            estado_nodo = nodo_actual.get_estado()
         #para que se genere si esta vivo o muerto
            hijo_generado =[] 
            #crear hijos y sus estados dependiendo en como ¿van
            hijo = [[estado_nodo[0][0],estado_nodo[0][1],estado_nodo[1][2],estado_nodo[1][3]], [estado_nodo[1][0],estado_nodo[1][1],estado_nodo[0][2],estado_nodo[0][3]]]
            hijo1 = Nodo(hijo)
            if muerto_vivo (hijo) == "vivo":
                hijo_generado.append(hijo1) 
            if not hijo1.en_lista(nodos_visitados) and not hijo1.en_lista(nodos_frontera):
                nodos_frontera.append(hijo1)


            hijo = [[estado_nodo[0][0],estado_nodo[1][1],estado_nodo[0][2],estado_nodo[1][3]], [estado_nodo[1][0],estado_nodo[0][1],estado_nodo[1][2],estado_nodo[0][3]]]
            hijo2 = Nodo(hijo)
            if muerto_vivo (hijo) == "vivo":
                hijo_generado.append(hijo2)
            if not hijo2.en_lista(nodos_visitados) and not hijo2.en_lista(nodos_frontera):
                nodos_frontera.append(hijo2)
         
            hijo = [[estado_nodo[1][0],estado_nodo[0][1],estado_nodo[0][2],estado_nodo[1][3]], [estado_nodo[0][0],estado_nodo[1][1],estado_nodo[1][2],estado_nodo[0][3]]]
            hijo3 = Nodo(hijo)
            if muerto_vivo (hijo) == "vivo":
                hijo_generado.append(hijo3)
            if not hijo3.en_lista(nodos_visitados) and not hijo3.en_lista(nodos_frontera):
                nodos_frontera.append(hijo3)
          
            hijo = [[estado_nodo[0][0],estado_nodo[0][1],estado_nodo[0][2],estado_nodo[1][3]], [estado_nodo[1][0],estado_nodo[1][1],estado_nodo[1][2],estado_nodo[0][3]]]
            hijo4 = Nodo(hijo)
            if muerto_vivo (hijo) == "vivo":
                hijo_generado.append(hijo4)
            if not hijo4.en_lista(nodos_visitados) and not hijo4.en_lista(nodos_frontera):
                nodos_frontera.append(hijo4)
            nodo_actual.set_hijo(hijo_generado)

# %%
#crear estado inicial y llevar a estado solucion
if __name__ == "__main__":
    estado_inicial = [["lo","ov", "le","pe"],["0","0","0","0"]]
    solucion = [["0","0","0","0"],["lo","ov", "le","pe"]]
    nodo_solucion = busqueda_BPA_solucion(estado_inicial, solucion)
    # mostrar resultado
    resultado = []
    nodo_actual = nodo_solucion
    while nodo_actual.get_padre() is not None:
        resultado.append(nodo_actual.get_estado())
        nodo_actual = nodo_actual.get_padre()

    resultado.append(estado_inicial)
    resultado.reverse()
    print(resultado)
# Out:
# [[['lo', 'ov', 'le', 'pe'], ['0', '0', '0', '0']], [['0', '0', '0', '0'], ['lo', 'ov', 'le', 'pe']]]
